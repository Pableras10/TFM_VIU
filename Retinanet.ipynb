# %%
# !pip install tensorflow
# !pip install keras-retinanet
# !pip install keras-resnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-retinanet
#   Downloading keras-retinanet-1.0.0.tar.gz (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 KB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting keras-resnet==0.2.0
#   Downloading keras-resnet-0.2.0.tar.gz (9.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (1.10.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (0.29.33)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (8.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (4.7.0.72)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.9/dist-packages (from keras-retinanet) (3.38.0)
# Requirement already satisfied: keras>=2.2.4 in /usr/local/lib/python3.9/dist-packages (from keras-resnet==0.2.0->keras-retinanet) (2.11.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python->keras-retinanet) (1.22.4)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from progressbar2->keras-retinanet) (3.5.2)
# Building wheels for collected packages: keras-retinanet, keras-resnet
#   Building wheel for keras-retinanet (setup.py) ... done
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp39-cp39-linux_x86_64.whl size=176582 sha256=82d0c21deb03250d9af296720c816d2bd5cbe5725c1da8a34f7ed8cd1e509d02
#   Stored in directory: /root/.cache/pip/wheels/e2/c8/81/3446d987ed6b58477ac44c8a07c7253e9f38e9c96adac6364c
#   Building wheel for keras-resnet (setup.py) ... done
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20484 sha256=2378b22222f352f895bdc33b0892bfc04b72bad0044d27f2808e024e0bfa6a87
#   Stored in directory: /root/.cache/pip/wheels/53/ed/ef/144804f160c278c80d6429c97ed126b61276721894ce64cccc
# Successfully built keras-retinanet keras-resnet
# Installing collected packages: keras-resnet, keras-retinanet
# Successfully installed keras-resnet-0.2.0 keras-retinanet-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-resnet in /usr/local/lib/python3.9/dist-packages (0.2.0)
# Requirement already satisfied: keras>=2.2.4 in /usr/local/lib/python3.9/dist-packages (from keras-resnet) (2.11.0)

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# %cd keras-retinanet
# !pip install .
# !python setup.py build_ext --inplace
# %cd ..
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6224, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 6224 (delta 6), reused 6 (delta 2), pack-reused 6205
# Receiving objects: 100% (6224/6224), 13.48 MiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (4207/4207), done.
# /content/keras-retinanet
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/keras-retinanet
#   Preparing metadata (setup.py) ... done
# Collecting keras-resnet==0.2.0
#   Downloading keras-resnet-0.2.0.tar.gz (9.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (1.22.4)
# Requirement already satisfied: cython in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (0.29.33)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (8.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (4.7.0.72)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.9/dist-packages (from keras-retinanet==1.0.0) (3.38.0)
# Requirement already satisfied: keras>=2.2.4 in /usr/local/lib/python3.9/dist-packages (from keras-resnet==0.2.0->keras-retinanet==1.0.0) (2.11.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from progressbar2->keras-retinanet==1.0.0) (3.5.2)
# Building wheels for collected packages: keras-retinanet, keras-resnet
#   Building wheel for keras-retinanet (setup.py) ... done
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp39-cp39-linux_x86_64.whl size=180745 sha256=086fc3a93d4cd024a81251b282b55ddbfe0aeedf7e48c1b4cc2a97d83f92f015
#   Stored in directory: /root/.cache/pip/wheels/3f/be/fa/528d5f2773281e6dd7795aa3039aea5a871e02ab5491117ad7
#   Building wheel for keras-resnet (setup.py) ... done
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20484 sha256=2b8c20f85da3c89290c1fec07e0a1f5aaa416727be85536a188fa7f472acd4fd
#   Stored in directory: /root/.cache/pip/wheels/53/ed/ef/144804f160c278c80d6429c97ed126b61276721894ce64cccc
# Successfully built keras-retinanet keras-resnet
# Installing collected packages: keras-resnet, keras-retinanet
# Successfully installed keras-resnet-0.2.0 keras-retinanet-1.0.0
# /usr/local/lib/python3.9/dist-packages/setuptools/__init__.py:85: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated. Requirements should be satisfied by a PEP 517 installer. If you are using pip, you can try `pip install --use-pep517`.
#   dist.fetch_build_eggs(dist.setup_requires)
# running build_ext
# skipping 'keras_retinanet/utils/compute_overlap.c' Cython extension (up-to-date)
# copying build/lib.linux-x86_64-3.9/keras_retinanet/utils/compute_overlap.cpython-39-x86_64-linux-gnu.so -> keras_retinanet/utils
# /content

# %%
import os 
import random
import shutil
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Read images and annotations
ruta = '/content/drive/MyDrive/TFM/DroneDatasetFinal/drone_dataset_yolo/dataset_txt'
images = [os.path.join(ruta, x) for x in os.listdir(ruta) if (x[-3:] == "jpg" or x[-4:] == "JPEG")]
labels = [os.path.join(ruta, x) for x in os.listdir(ruta) if x[-3:] == "txt"]

print(len(images))
print(len(labels))

images.sort()
labels.sort()

# Split the dataset into train-valid-test splits 
train_images = images
train_labels = labels
#train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size = 0.2, random_state = 1)
# Out:
# 4228
# 4228

# %%
# !mkdir -p keras-retinanet/train/images keras-retinanet/train/annotations

# %%
def move_files_to_folder(list_of_files, destination_folder):
    for f in list_of_files:
        try:
            shutil.copy(f, destination_folder)
        except:
            print(f)
            assert False

# Move the splits into their folders
move_files_to_folder(train_images, 'keras-retinanet/train/images')
move_files_to_folder(train_labels, 'keras-retinanet/train/annotations')

# %%
#rename jpeg to jpg
source_dir = 'keras-retinanet/train/images'
files = os.listdir(source_dir)

for file in files:
    if file.lower().endswith('.jpeg'):
        old_path = os.path.join(source_dir, file)
        new_path = os.path.join(source_dir, file.lower().replace('.jpeg', '.jpg'))
        os.rename(old_path, new_path)

print('Renaming completed.')
# Out:
# Renaming completed.

# %%
#convert yolo format to retinanet annotation csv
import os
import glob
from PIL import Image

IMAGE_DIR = "keras-retinanet/train/images"
ANNOTATION_DIR = "keras-retinanet/train/annotations"
OUTPUT_FILE = "retinanet_train_annotations.csv"
CLASS_NAMES = ['drone']  # Replace with your class names

def yolo_to_retinanet(yolo_annotation, img_width, img_height):
    class_id, x_center, y_center, width, height = map(float, yolo_annotation.strip().split())

    x_min = (x_center - width / 2) * img_width
    x_max = (x_center + width / 2) * img_width
    y_min = (y_center - height / 2) * img_height
    y_max = (y_center + height / 2) * img_height

    return int(class_id), x_min, y_min, x_max, y_max

with open(OUTPUT_FILE, 'w') as output_file:
    for ann_file in glob.glob(os.path.join(ANNOTATION_DIR, '*.txt')):
        img_file = os.path.join(IMAGE_DIR, os.path.splitext(os.path.basename(ann_file))[0] + '.jpg')

        # verify whether image exists
        if not os.path.exists(img_file):
            continue

        img = Image.open(img_file)
        img_width, img_height = img.size

        with open(ann_file, 'r') as yolo_ann:
            for line in yolo_ann:
                class_id, x_min, y_min, x_max, y_max = yolo_to_retinanet(line, img_width, img_height)
                class_name = CLASS_NAMES[class_id]
                x_min = int(x_min)
                y_min = int(y_min)
                x_max = int(x_max)
                y_max = int(y_max)
                output_line = f"{img_file},{x_min},{y_min},{x_max},{y_max},{class_name}\n"
                output_file.write(output_line)

# %%
#train model
# !keras-retinanet/keras_retinanet/bin/train.py \
  --weights keras-retinanet/snapshots/resnet50_coco_best_v2.0.1.h5 \
  --epochs 200 \
  --steps 100 \
  --batch-size 1 \
  --snapshot-path snapshots2 \
  --freeze-backbone \
  --random-transform \
  --tensorboard-dir logs \
  csv /content/retinanet_train_annotations.csv keras-retinanet/classes.csv


 # !keras_retinanet/bin/train.py --freeze-backbone \ --random-transform \ --weights {PRETRAINED_MODEL} \ --batch-size 8 \ --steps 500 \ --epochs 15 \ csv maskDetectorData.csv maskDetectorClasses.csv
# Out:
# 2023-03-29 10:45:03.035286: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 10:45:04.015330: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-29 10:45:04.015512: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-29 10:45:04.015556: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Creating model, this may take a second...
# 2023-03-29 10:45:08.708353: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:Skipping loading weights for layer #210 (named classification_submodel) due to mismatch in shape for weight pyramid_classification/kernel:0. Weight expects shape (3, 3, 256, 9). Received saved weight with shape (720, 256, 3, 3)
# WARNING:tensorflow:Skipping loading weights for layer #210 (named classification_submodel) due to mismatch in shape for weight pyramid_classification/bias:0. Weight expects shape (9,). Received saved weight with shape (720,)
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "retinanet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1 (Conv2D)                 (None, None, None,   9408        ['input_1[0][0]']
#                                 64)
#
#  bn_conv1 (BatchNormalization)  (None, None, None,   256         ['conv1[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['bn_conv1[0][0]']
#                                 64)
#
#  pool1 (MaxPooling2D)           (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
#  res2a_branch2a (Conv2D)        (None, None, None,   4096        ['pool1[0][0]']
#                                 64)
#
#  bn2a_branch2a (BatchNormalizat  (None, None, None,   256        ['res2a_branch2a[0][0]']
#  ion)                           64)
#
#  res2a_branch2a_relu (Activatio  (None, None, None,   0          ['bn2a_branch2a[0][0]']
#  n)                             64)
#
#  padding2a_branch2b (ZeroPaddin  (None, None, None,   0          ['res2a_branch2a_relu[0][0]']
#  g2D)                           64)
#
#  res2a_branch2b (Conv2D)        (None, None, None,   36864       ['padding2a_branch2b[0][0]']
#                                 64)
#
#  bn2a_branch2b (BatchNormalizat  (None, None, None,   256        ['res2a_branch2b[0][0]']
#  ion)                           64)
#
#  res2a_branch2b_relu (Activatio  (None, None, None,   0          ['bn2a_branch2b[0][0]']
#  n)                             64)
#
#  res2a_branch2c (Conv2D)        (None, None, None,   16384       ['res2a_branch2b_relu[0][0]']
#                                 256)
#
#  res2a_branch1 (Conv2D)         (None, None, None,   16384       ['pool1[0][0]']
#                                 256)
#
#  bn2a_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2a_branch2c[0][0]']
#  ion)                           256)
#
#  bn2a_branch1 (BatchNormalizati  (None, None, None,   1024       ['res2a_branch1[0][0]']
#  on)                            256)
#
#  res2a (Add)                    (None, None, None,   0           ['bn2a_branch2c[0][0]',
#                                 256)                              'bn2a_branch1[0][0]']
#
#  res2a_relu (Activation)        (None, None, None,   0           ['res2a[0][0]']
#                                 256)
#
#  res2b_branch2a (Conv2D)        (None, None, None,   16384       ['res2a_relu[0][0]']
#                                 64)
#
#  bn2b_branch2a (BatchNormalizat  (None, None, None,   256        ['res2b_branch2a[0][0]']
#  ion)                           64)
#
#  res2b_branch2a_relu (Activatio  (None, None, None,   0          ['bn2b_branch2a[0][0]']
#  n)                             64)
#
#  padding2b_branch2b (ZeroPaddin  (None, None, None,   0          ['res2b_branch2a_relu[0][0]']
#  g2D)                           64)
#
#  res2b_branch2b (Conv2D)        (None, None, None,   36864       ['padding2b_branch2b[0][0]']
#                                 64)
#
#  bn2b_branch2b (BatchNormalizat  (None, None, None,   256        ['res2b_branch2b[0][0]']
#  ion)                           64)
#
#  res2b_branch2b_relu (Activatio  (None, None, None,   0          ['bn2b_branch2b[0][0]']
#  n)                             64)
#
#  res2b_branch2c (Conv2D)        (None, None, None,   16384       ['res2b_branch2b_relu[0][0]']
#                                 256)
#
#  bn2b_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2b_branch2c[0][0]']
#  ion)                           256)
#
#  res2b (Add)                    (None, None, None,   0           ['bn2b_branch2c[0][0]',
#                                 256)                              'res2a_relu[0][0]']
#
#  res2b_relu (Activation)        (None, None, None,   0           ['res2b[0][0]']
#                                 256)
#
#  res2c_branch2a (Conv2D)        (None, None, None,   16384       ['res2b_relu[0][0]']
#                                 64)
#
#  bn2c_branch2a (BatchNormalizat  (None, None, None,   256        ['res2c_branch2a[0][0]']
#  ion)                           64)
#
#  res2c_branch2a_relu (Activatio  (None, None, None,   0          ['bn2c_branch2a[0][0]']
#  n)                             64)
#
#  padding2c_branch2b (ZeroPaddin  (None, None, None,   0          ['res2c_branch2a_relu[0][0]']
#  g2D)                           64)
#
#  res2c_branch2b (Conv2D)        (None, None, None,   36864       ['padding2c_branch2b[0][0]']
#                                 64)
#
#  bn2c_branch2b (BatchNormalizat  (None, None, None,   256        ['res2c_branch2b[0][0]']
#  ion)                           64)
#
#  res2c_branch2b_relu (Activatio  (None, None, None,   0          ['bn2c_branch2b[0][0]']
#  n)                             64)
#
#  res2c_branch2c (Conv2D)        (None, None, None,   16384       ['res2c_branch2b_relu[0][0]']
#                                 256)
#
#  bn2c_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2c_branch2c[0][0]']
#  ion)                           256)
#
#  res2c (Add)                    (None, None, None,   0           ['bn2c_branch2c[0][0]',
#                                 256)                              'res2b_relu[0][0]']
#
#  res2c_relu (Activation)        (None, None, None,   0           ['res2c[0][0]']
#                                 256)
#
#  res3a_branch2a (Conv2D)        (None, None, None,   32768       ['res2c_relu[0][0]']
#                                 128)
#
#  bn3a_branch2a (BatchNormalizat  (None, None, None,   512        ['res3a_branch2a[0][0]']
#  ion)                           128)
#
#  res3a_branch2a_relu (Activatio  (None, None, None,   0          ['bn3a_branch2a[0][0]']
#  n)                             128)
#
#  padding3a_branch2b (ZeroPaddin  (None, None, None,   0          ['res3a_branch2a_relu[0][0]']
#  g2D)                           128)
#
#  res3a_branch2b (Conv2D)        (None, None, None,   147456      ['padding3a_branch2b[0][0]']
#                                 128)
#
#  bn3a_branch2b (BatchNormalizat  (None, None, None,   512        ['res3a_branch2b[0][0]']
#  ion)                           128)
#
#  res3a_branch2b_relu (Activatio  (None, None, None,   0          ['bn3a_branch2b[0][0]']
#  n)                             128)
#
#  res3a_branch2c (Conv2D)        (None, None, None,   65536       ['res3a_branch2b_relu[0][0]']
#                                 512)
#
#  res3a_branch1 (Conv2D)         (None, None, None,   131072      ['res2c_relu[0][0]']
#                                 512)
#
#  bn3a_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3a_branch2c[0][0]']
#  ion)                           512)
#
#  bn3a_branch1 (BatchNormalizati  (None, None, None,   2048       ['res3a_branch1[0][0]']
#  on)                            512)
#
#  res3a (Add)                    (None, None, None,   0           ['bn3a_branch2c[0][0]',
#                                 512)                              'bn3a_branch1[0][0]']
#
#  res3a_relu (Activation)        (None, None, None,   0           ['res3a[0][0]']
#                                 512)
#
#  res3b_branch2a (Conv2D)        (None, None, None,   65536       ['res3a_relu[0][0]']
#                                 128)
#
#  bn3b_branch2a (BatchNormalizat  (None, None, None,   512        ['res3b_branch2a[0][0]']
#  ion)                           128)
#
#  res3b_branch2a_relu (Activatio  (None, None, None,   0          ['bn3b_branch2a[0][0]']
#  n)                             128)
#
#  padding3b_branch2b (ZeroPaddin  (None, None, None,   0          ['res3b_branch2a_relu[0][0]']
#  g2D)                           128)
#
#  res3b_branch2b (Conv2D)        (None, None, None,   147456      ['padding3b_branch2b[0][0]']
#                                 128)
#
#  bn3b_branch2b (BatchNormalizat  (None, None, None,   512        ['res3b_branch2b[0][0]']
#  ion)                           128)
#
#  res3b_branch2b_relu (Activatio  (None, None, None,   0          ['bn3b_branch2b[0][0]']
#  n)                             128)
#
#  res3b_branch2c (Conv2D)        (None, None, None,   65536       ['res3b_branch2b_relu[0][0]']
#                                 512)
#
#  bn3b_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3b_branch2c[0][0]']
#  ion)                           512)
#
#  res3b (Add)                    (None, None, None,   0           ['bn3b_branch2c[0][0]',
#                                 512)                              'res3a_relu[0][0]']
#
#  res3b_relu (Activation)        (None, None, None,   0           ['res3b[0][0]']
#                                 512)
#
#  res3c_branch2a (Conv2D)        (None, None, None,   65536       ['res3b_relu[0][0]']
#                                 128)
#
#  bn3c_branch2a (BatchNormalizat  (None, None, None,   512        ['res3c_branch2a[0][0]']
#  ion)                           128)
#
#  res3c_branch2a_relu (Activatio  (None, None, None,   0          ['bn3c_branch2a[0][0]']
#  n)                             128)
#
#  padding3c_branch2b (ZeroPaddin  (None, None, None,   0          ['res3c_branch2a_relu[0][0]']
#  g2D)                           128)
#
#  res3c_branch2b (Conv2D)        (None, None, None,   147456      ['padding3c_branch2b[0][0]']
#                                 128)
#
#  bn3c_branch2b (BatchNormalizat  (None, None, None,   512        ['res3c_branch2b[0][0]']
#  ion)                           128)
#
#  res3c_branch2b_relu (Activatio  (None, None, None,   0          ['bn3c_branch2b[0][0]']
#  n)                             128)
#
#  res3c_branch2c (Conv2D)        (None, None, None,   65536       ['res3c_branch2b_relu[0][0]']
#                                 512)
#
#  bn3c_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3c_branch2c[0][0]']
#  ion)                           512)
#
#  res3c (Add)                    (None, None, None,   0           ['bn3c_branch2c[0][0]',
#                                 512)                              'res3b_relu[0][0]']
#
#  res3c_relu (Activation)        (None, None, None,   0           ['res3c[0][0]']
#                                 512)
#
#  res3d_branch2a (Conv2D)        (None, None, None,   65536       ['res3c_relu[0][0]']
#                                 128)
#
#  bn3d_branch2a (BatchNormalizat  (None, None, None,   512        ['res3d_branch2a[0][0]']
#  ion)                           128)
#
#  res3d_branch2a_relu (Activatio  (None, None, None,   0          ['bn3d_branch2a[0][0]']
#  n)                             128)
#
#  padding3d_branch2b (ZeroPaddin  (None, None, None,   0          ['res3d_branch2a_relu[0][0]']
#  g2D)                           128)
#
#  res3d_branch2b (Conv2D)        (None, None, None,   147456      ['padding3d_branch2b[0][0]']
#                                 128)
#
#  bn3d_branch2b (BatchNormalizat  (None, None, None,   512        ['res3d_branch2b[0][0]']
#  ion)                           128)
#
#  res3d_branch2b_relu (Activatio  (None, None, None,   0          ['bn3d_branch2b[0][0]']
#  n)                             128)
#
#  res3d_branch2c (Conv2D)        (None, None, None,   65536       ['res3d_branch2b_relu[0][0]']
#                                 512)
#
#  bn3d_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3d_branch2c[0][0]']
#  ion)                           512)
#
#  res3d (Add)                    (None, None, None,   0           ['bn3d_branch2c[0][0]',
#                                 512)                              'res3c_relu[0][0]']
#
#  res3d_relu (Activation)        (None, None, None,   0           ['res3d[0][0]']
#                                 512)
#
#  res4a_branch2a (Conv2D)        (None, None, None,   131072      ['res3d_relu[0][0]']
#                                 256)
#
#  bn4a_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4a_branch2a[0][0]']
#  ion)                           256)
#
#  res4a_branch2a_relu (Activatio  (None, None, None,   0          ['bn4a_branch2a[0][0]']
#  n)                             256)
#
#  padding4a_branch2b (ZeroPaddin  (None, None, None,   0          ['res4a_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4a_branch2b (Conv2D)        (None, None, None,   589824      ['padding4a_branch2b[0][0]']
#                                 256)
#
#  bn4a_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4a_branch2b[0][0]']
#  ion)                           256)
#
#  res4a_branch2b_relu (Activatio  (None, None, None,   0          ['bn4a_branch2b[0][0]']
#  n)                             256)
#
#  res4a_branch2c (Conv2D)        (None, None, None,   262144      ['res4a_branch2b_relu[0][0]']
#                                 1024)
#
#  res4a_branch1 (Conv2D)         (None, None, None,   524288      ['res3d_relu[0][0]']
#                                 1024)
#
#  bn4a_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4a_branch2c[0][0]']
#  ion)                           1024)
#
#  bn4a_branch1 (BatchNormalizati  (None, None, None,   4096       ['res4a_branch1[0][0]']
#  on)                            1024)
#
#  res4a (Add)                    (None, None, None,   0           ['bn4a_branch2c[0][0]',
#                                 1024)                             'bn4a_branch1[0][0]']
#
#  res4a_relu (Activation)        (None, None, None,   0           ['res4a[0][0]']
#                                 1024)
#
#  res4b_branch2a (Conv2D)        (None, None, None,   262144      ['res4a_relu[0][0]']
#                                 256)
#
#  bn4b_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4b_branch2a[0][0]']
#  ion)                           256)
#
#  res4b_branch2a_relu (Activatio  (None, None, None,   0          ['bn4b_branch2a[0][0]']
#  n)                             256)
#
#  padding4b_branch2b (ZeroPaddin  (None, None, None,   0          ['res4b_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4b_branch2b (Conv2D)        (None, None, None,   589824      ['padding4b_branch2b[0][0]']
#                                 256)
#
#  bn4b_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4b_branch2b[0][0]']
#  ion)                           256)
#
#  res4b_branch2b_relu (Activatio  (None, None, None,   0          ['bn4b_branch2b[0][0]']
#  n)                             256)
#
#  res4b_branch2c (Conv2D)        (None, None, None,   262144      ['res4b_branch2b_relu[0][0]']
#                                 1024)
#
#  bn4b_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4b_branch2c[0][0]']
#  ion)                           1024)
#
#  res4b (Add)                    (None, None, None,   0           ['bn4b_branch2c[0][0]',
#                                 1024)                             'res4a_relu[0][0]']
#
#  res4b_relu (Activation)        (None, None, None,   0           ['res4b[0][0]']
#                                 1024)
#
#  res4c_branch2a (Conv2D)        (None, None, None,   262144      ['res4b_relu[0][0]']
#                                 256)
#
#  bn4c_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4c_branch2a[0][0]']
#  ion)                           256)
#
#  res4c_branch2a_relu (Activatio  (None, None, None,   0          ['bn4c_branch2a[0][0]']
#  n)                             256)
#
#  padding4c_branch2b (ZeroPaddin  (None, None, None,   0          ['res4c_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4c_branch2b (Conv2D)        (None, None, None,   589824      ['padding4c_branch2b[0][0]']
#                                 256)
#
#  bn4c_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4c_branch2b[0][0]']
#  ion)                           256)
#
#  res4c_branch2b_relu (Activatio  (None, None, None,   0          ['bn4c_branch2b[0][0]']
#  n)                             256)
#
#  res4c_branch2c (Conv2D)        (None, None, None,   262144      ['res4c_branch2b_relu[0][0]']
#                                 1024)
#
#  bn4c_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4c_branch2c[0][0]']
#  ion)                           1024)
#
#  res4c (Add)                    (None, None, None,   0           ['bn4c_branch2c[0][0]',
#                                 1024)                             'res4b_relu[0][0]']
#
#  res4c_relu (Activation)        (None, None, None,   0           ['res4c[0][0]']
#                                 1024)
#
#  res4d_branch2a (Conv2D)        (None, None, None,   262144      ['res4c_relu[0][0]']
#                                 256)
#
#  bn4d_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4d_branch2a[0][0]']
#  ion)                           256)
#
#  res4d_branch2a_relu (Activatio  (None, None, None,   0          ['bn4d_branch2a[0][0]']
#  n)                             256)
#
#  padding4d_branch2b (ZeroPaddin  (None, None, None,   0          ['res4d_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4d_branch2b (Conv2D)        (None, None, None,   589824      ['padding4d_branch2b[0][0]']
#                                 256)
#
#  bn4d_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4d_branch2b[0][0]']
#  ion)                           256)
#
#  res4d_branch2b_relu (Activatio  (None, None, None,   0          ['bn4d_branch2b[0][0]']
#  n)                             256)
#
#  res4d_branch2c (Conv2D)        (None, None, None,   262144      ['res4d_branch2b_relu[0][0]']
#                                 1024)
#
#  bn4d_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4d_branch2c[0][0]']
#  ion)                           1024)
#
#  res4d (Add)                    (None, None, None,   0           ['bn4d_branch2c[0][0]',
#                                 1024)                             'res4c_relu[0][0]']
#
#  res4d_relu (Activation)        (None, None, None,   0           ['res4d[0][0]']
#                                 1024)
#
#  res4e_branch2a (Conv2D)        (None, None, None,   262144      ['res4d_relu[0][0]']
#                                 256)
#
#  bn4e_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4e_branch2a[0][0]']
#  ion)                           256)
#
#  res4e_branch2a_relu (Activatio  (None, None, None,   0          ['bn4e_branch2a[0][0]']
#  n)                             256)
#
#  padding4e_branch2b (ZeroPaddin  (None, None, None,   0          ['res4e_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4e_branch2b (Conv2D)        (None, None, None,   589824      ['padding4e_branch2b[0][0]']
#                                 256)
#
#  bn4e_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4e_branch2b[0][0]']
#  ion)                           256)
#
#  res4e_branch2b_relu (Activatio  (None, None, None,   0          ['bn4e_branch2b[0][0]']
#  n)                             256)
#
#  res4e_branch2c (Conv2D)        (None, None, None,   262144      ['res4e_branch2b_relu[0][0]']
#                                 1024)
#
#  bn4e_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4e_branch2c[0][0]']
#  ion)                           1024)
#
#  res4e (Add)                    (None, None, None,   0           ['bn4e_branch2c[0][0]',
#                                 1024)                             'res4d_relu[0][0]']
#
#  res4e_relu (Activation)        (None, None, None,   0           ['res4e[0][0]']
#                                 1024)
#
#  res4f_branch2a (Conv2D)        (None, None, None,   262144      ['res4e_relu[0][0]']
#                                 256)
#
#  bn4f_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4f_branch2a[0][0]']
#  ion)                           256)
#
#  res4f_branch2a_relu (Activatio  (None, None, None,   0          ['bn4f_branch2a[0][0]']
#  n)                             256)
#
#  padding4f_branch2b (ZeroPaddin  (None, None, None,   0          ['res4f_branch2a_relu[0][0]']
#  g2D)                           256)
#
#  res4f_branch2b (Conv2D)        (None, None, None,   589824      ['padding4f_branch2b[0][0]']
#                                 256)
#
#  bn4f_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4f_branch2b[0][0]']
#  ion)                           256)
#
#  res4f_branch2b_relu (Activatio  (None, None, None,   0          ['bn4f_branch2b[0][0]']
#  n)                             256)
#
#  res4f_branch2c (Conv2D)        (None, None, None,   262144      ['res4f_branch2b_relu[0][0]']
#                                 1024)
# ...
# Epoch 154/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0060 - regression_loss: 1.6949 - classification_loss: 0.3110
# Epoch 154: saving model to snapshots2/resnet50_csv_154.h5
# 100/100 [==============================] - 20s 196ms/step - loss: 2.0060 - regression_loss: 1.6949 - classification_loss: 0.3110 - lr: 0.0000e+00
# Epoch 155/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8374 - regression_loss: 1.5946 - classification_loss: 0.2427
# Epoch 155: saving model to snapshots2/resnet50_csv_155.h5
# 100/100 [==============================] - 21s 205ms/step - loss: 1.8374 - regression_loss: 1.5946 - classification_loss: 0.2427 - lr: 0.0000e+00
# Epoch 156/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9225 - regression_loss: 1.6171 - classification_loss: 0.3054
# Epoch 156: saving model to snapshots2/resnet50_csv_156.h5
# 100/100 [==============================] - 20s 196ms/step - loss: 1.9225 - regression_loss: 1.6171 - classification_loss: 0.3054 - lr: 0.0000e+00
# Epoch 157/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9115 - regression_loss: 1.6186 - classification_loss: 0.2929
# Epoch 157: saving model to snapshots2/resnet50_csv_157.h5
# 100/100 [==============================] - 23s 227ms/step - loss: 1.9115 - regression_loss: 1.6186 - classification_loss: 0.2929 - lr: 0.0000e+00
# Epoch 158/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0158 - regression_loss: 1.7199 - classification_loss: 0.2959
# Epoch 158: saving model to snapshots2/resnet50_csv_158.h5
# 100/100 [==============================] - 21s 204ms/step - loss: 2.0158 - regression_loss: 1.7199 - classification_loss: 0.2959 - lr: 0.0000e+00
# Epoch 159/200
# 100/100 [==============================] - ETA: 0s - loss: 1.6986 - regression_loss: 1.4664 - classification_loss: 0.2323
# Epoch 159: saving model to snapshots2/resnet50_csv_159.h5
# 100/100 [==============================] - 20s 201ms/step - loss: 1.6986 - regression_loss: 1.4664 - classification_loss: 0.2323 - lr: 0.0000e+00
# Epoch 160/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0229 - regression_loss: 1.7231 - classification_loss: 0.2999
# Epoch 160: saving model to snapshots2/resnet50_csv_160.h5
# 100/100 [==============================] - 21s 205ms/step - loss: 2.0229 - regression_loss: 1.7231 - classification_loss: 0.2999 - lr: 0.0000e+00
# Epoch 161/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8205 - regression_loss: 1.5561 - classification_loss: 0.2644
# Epoch 161: saving model to snapshots2/resnet50_csv_161.h5
# 100/100 [==============================] - 20s 195ms/step - loss: 1.8205 - regression_loss: 1.5561 - classification_loss: 0.2644 - lr: 0.0000e+00
# Epoch 162/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9759 - regression_loss: 1.6734 - classification_loss: 0.3025
# Epoch 162: saving model to snapshots2/resnet50_csv_162.h5
# 100/100 [==============================] - 20s 200ms/step - loss: 1.9759 - regression_loss: 1.6734 - classification_loss: 0.3025 - lr: 0.0000e+00
# Epoch 163/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9344 - regression_loss: 1.6442 - classification_loss: 0.2903
# Epoch 163: saving model to snapshots2/resnet50_csv_163.h5
# 100/100 [==============================] - 21s 210ms/step - loss: 1.9344 - regression_loss: 1.6442 - classification_loss: 0.2903 - lr: 0.0000e+00
# Epoch 164/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8860 - regression_loss: 1.5948 - classification_loss: 0.2912
# Epoch 164: saving model to snapshots2/resnet50_csv_164.h5
# 100/100 [==============================] - 21s 207ms/step - loss: 1.8860 - regression_loss: 1.5948 - classification_loss: 0.2912 - lr: 0.0000e+00
# Epoch 165/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9314 - regression_loss: 1.6502 - classification_loss: 0.2812
# Epoch 165: saving model to snapshots2/resnet50_csv_165.h5
# 100/100 [==============================] - 20s 203ms/step - loss: 1.9314 - regression_loss: 1.6502 - classification_loss: 0.2812 - lr: 0.0000e+00
# Epoch 166/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8266 - regression_loss: 1.5865 - classification_loss: 0.2401
# Epoch 166: saving model to snapshots2/resnet50_csv_166.h5
# 100/100 [==============================] - 20s 199ms/step - loss: 1.8266 - regression_loss: 1.5865 - classification_loss: 0.2401 - lr: 0.0000e+00
# Epoch 167/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8968 - regression_loss: 1.6194 - classification_loss: 0.2774
# Epoch 167: saving model to snapshots2/resnet50_csv_167.h5
# 100/100 [==============================] - 20s 197ms/step - loss: 1.8968 - regression_loss: 1.6194 - classification_loss: 0.2774 - lr: 0.0000e+00
# Epoch 168/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9342 - regression_loss: 1.6428 - classification_loss: 0.2914
# Epoch 168: saving model to snapshots2/resnet50_csv_168.h5
# 100/100 [==============================] - 21s 212ms/step - loss: 1.9342 - regression_loss: 1.6428 - classification_loss: 0.2914 - lr: 0.0000e+00
# Epoch 169/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9788 - regression_loss: 1.7008 - classification_loss: 0.2780
# Epoch 169: saving model to snapshots2/resnet50_csv_169.h5
# 100/100 [==============================] - 20s 201ms/step - loss: 1.9788 - regression_loss: 1.7008 - classification_loss: 0.2780 - lr: 0.0000e+00
# Epoch 170/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8084 - regression_loss: 1.5224 - classification_loss: 0.2860
# Epoch 170: saving model to snapshots2/resnet50_csv_170.h5
# 100/100 [==============================] - 20s 204ms/step - loss: 1.8084 - regression_loss: 1.5224 - classification_loss: 0.2860 - lr: 0.0000e+00
# Epoch 171/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8194 - regression_loss: 1.5598 - classification_loss: 0.2596
# Epoch 171: saving model to snapshots2/resnet50_csv_171.h5
# 100/100 [==============================] - 20s 203ms/step - loss: 1.8194 - regression_loss: 1.5598 - classification_loss: 0.2596 - lr: 0.0000e+00
# Epoch 172/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9732 - regression_loss: 1.6665 - classification_loss: 0.3067
# Epoch 172: saving model to snapshots2/resnet50_csv_172.h5
# 100/100 [==============================] - 20s 198ms/step - loss: 1.9732 - regression_loss: 1.6665 - classification_loss: 0.3067 - lr: 0.0000e+00
# Epoch 173/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9230 - regression_loss: 1.5873 - classification_loss: 0.3357
# Epoch 173: saving model to snapshots2/resnet50_csv_173.h5
# 100/100 [==============================] - 20s 199ms/step - loss: 1.9230 - regression_loss: 1.5873 - classification_loss: 0.3357 - lr: 0.0000e+00
# Epoch 174/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0792 - regression_loss: 1.7395 - classification_loss: 0.3396
# Epoch 174: saving model to snapshots2/resnet50_csv_174.h5
# 100/100 [==============================] - 20s 203ms/step - loss: 2.0792 - regression_loss: 1.7395 - classification_loss: 0.3396 - lr: 0.0000e+00
# Epoch 175/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9493 - regression_loss: 1.6667 - classification_loss: 0.2825
# Epoch 175: saving model to snapshots2/resnet50_csv_175.h5
# 100/100 [==============================] - 21s 213ms/step - loss: 1.9493 - regression_loss: 1.6667 - classification_loss: 0.2825 - lr: 0.0000e+00
# Epoch 176/200
# 100/100 [==============================] - ETA: 0s - loss: 2.1113 - regression_loss: 1.6759 - classification_loss: 0.4354
# Epoch 176: saving model to snapshots2/resnet50_csv_176.h5
# 100/100 [==============================] - 20s 202ms/step - loss: 2.1113 - regression_loss: 1.6759 - classification_loss: 0.4354 - lr: 0.0000e+00
# Epoch 177/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8993 - regression_loss: 1.6123 - classification_loss: 0.2871
# Epoch 177: saving model to snapshots2/resnet50_csv_177.h5
# 100/100 [==============================] - 22s 215ms/step - loss: 1.8993 - regression_loss: 1.6123 - classification_loss: 0.2871 - lr: 0.0000e+00
# Epoch 178/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0056 - regression_loss: 1.7002 - classification_loss: 0.3054
# Epoch 178: saving model to snapshots2/resnet50_csv_178.h5
# 100/100 [==============================] - 19s 190ms/step - loss: 2.0056 - regression_loss: 1.7002 - classification_loss: 0.3054 - lr: 0.0000e+00
# Epoch 179/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9456 - regression_loss: 1.5658 - classification_loss: 0.3798
# Epoch 179: saving model to snapshots2/resnet50_csv_179.h5
# 100/100 [==============================] - 20s 204ms/step - loss: 1.9456 - regression_loss: 1.5658 - classification_loss: 0.3798 - lr: 0.0000e+00
# Epoch 180/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9257 - regression_loss: 1.6479 - classification_loss: 0.2778
# Epoch 180: saving model to snapshots2/resnet50_csv_180.h5
# 100/100 [==============================] - 25s 250ms/step - loss: 1.9257 - regression_loss: 1.6479 - classification_loss: 0.2778 - lr: 0.0000e+00
# Epoch 181/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9272 - regression_loss: 1.6562 - classification_loss: 0.2711
# Epoch 181: saving model to snapshots2/resnet50_csv_181.h5
# 100/100 [==============================] - 21s 206ms/step - loss: 1.9272 - regression_loss: 1.6562 - classification_loss: 0.2711 - lr: 0.0000e+00
# Epoch 182/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9653 - regression_loss: 1.6634 - classification_loss: 0.3019
# Epoch 182: saving model to snapshots2/resnet50_csv_182.h5
# 100/100 [==============================] - 21s 209ms/step - loss: 1.9653 - regression_loss: 1.6634 - classification_loss: 0.3019 - lr: 0.0000e+00
# Epoch 183/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0508 - regression_loss: 1.7076 - classification_loss: 0.3432
# Epoch 183: saving model to snapshots2/resnet50_csv_183.h5
# 100/100 [==============================] - 21s 205ms/step - loss: 2.0508 - regression_loss: 1.7076 - classification_loss: 0.3432 - lr: 0.0000e+00
# Epoch 184/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8384 - regression_loss: 1.5667 - classification_loss: 0.2716
# Epoch 184: saving model to snapshots2/resnet50_csv_184.h5
# 100/100 [==============================] - 21s 205ms/step - loss: 1.8384 - regression_loss: 1.5667 - classification_loss: 0.2716 - lr: 0.0000e+00
# Epoch 185/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0396 - regression_loss: 1.7153 - classification_loss: 0.3243
# Epoch 185: saving model to snapshots2/resnet50_csv_185.h5
# 100/100 [==============================] - 21s 212ms/step - loss: 2.0396 - regression_loss: 1.7153 - classification_loss: 0.3243 - lr: 0.0000e+00
# Epoch 186/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9148 - regression_loss: 1.6552 - classification_loss: 0.2596
# Epoch 186: saving model to snapshots2/resnet50_csv_186.h5
# 100/100 [==============================] - 20s 202ms/step - loss: 1.9148 - regression_loss: 1.6552 - classification_loss: 0.2596 - lr: 0.0000e+00
# Epoch 187/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8755 - regression_loss: 1.6016 - classification_loss: 0.2739
# Epoch 187: saving model to snapshots2/resnet50_csv_187.h5
# 100/100 [==============================] - 20s 195ms/step - loss: 1.8755 - regression_loss: 1.6016 - classification_loss: 0.2739 - lr: 0.0000e+00
# Epoch 188/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8358 - regression_loss: 1.5669 - classification_loss: 0.2689
# Epoch 188: saving model to snapshots2/resnet50_csv_188.h5
# 100/100 [==============================] - 20s 201ms/step - loss: 1.8358 - regression_loss: 1.5669 - classification_loss: 0.2689 - lr: 0.0000e+00
# Epoch 189/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9354 - regression_loss: 1.6240 - classification_loss: 0.3114
# Epoch 189: saving model to snapshots2/resnet50_csv_189.h5
# 100/100 [==============================] - 22s 223ms/step - loss: 1.9354 - regression_loss: 1.6240 - classification_loss: 0.3114 - lr: 0.0000e+00
# Epoch 190/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9539 - regression_loss: 1.6009 - classification_loss: 0.3530
# Epoch 190: saving model to snapshots2/resnet50_csv_190.h5
# 100/100 [==============================] - 26s 260ms/step - loss: 1.9539 - regression_loss: 1.6009 - classification_loss: 0.3530 - lr: 0.0000e+00
# Epoch 191/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9433 - regression_loss: 1.6602 - classification_loss: 0.2830
# Epoch 191: saving model to snapshots2/resnet50_csv_191.h5
# 100/100 [==============================] - 22s 214ms/step - loss: 1.9433 - regression_loss: 1.6602 - classification_loss: 0.2830 - lr: 0.0000e+00
# Epoch 192/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9325 - regression_loss: 1.6101 - classification_loss: 0.3224
# Epoch 192: saving model to snapshots2/resnet50_csv_192.h5
# 100/100 [==============================] - 20s 201ms/step - loss: 1.9325 - regression_loss: 1.6101 - classification_loss: 0.3224 - lr: 0.0000e+00
# Epoch 193/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9239 - regression_loss: 1.5963 - classification_loss: 0.3276
# Epoch 193: saving model to snapshots2/resnet50_csv_193.h5
# 100/100 [==============================] - 26s 259ms/step - loss: 1.9239 - regression_loss: 1.5963 - classification_loss: 0.3276 - lr: 0.0000e+00
# Epoch 194/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8645 - regression_loss: 1.5573 - classification_loss: 0.3072
# Epoch 194: saving model to snapshots2/resnet50_csv_194.h5
# 100/100 [==============================] - 20s 202ms/step - loss: 1.8645 - regression_loss: 1.5573 - classification_loss: 0.3072 - lr: 0.0000e+00
# Epoch 195/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8561 - regression_loss: 1.5522 - classification_loss: 0.3039
# Epoch 195: saving model to snapshots2/resnet50_csv_195.h5
# 100/100 [==============================] - 23s 224ms/step - loss: 1.8561 - regression_loss: 1.5522 - classification_loss: 0.3039 - lr: 0.0000e+00
# Epoch 196/200
# 100/100 [==============================] - ETA: 0s - loss: 1.8347 - regression_loss: 1.5278 - classification_loss: 0.3069
# Epoch 196: saving model to snapshots2/resnet50_csv_196.h5
# 100/100 [==============================] - 20s 200ms/step - loss: 1.8347 - regression_loss: 1.5278 - classification_loss: 0.3069 - lr: 0.0000e+00
# Epoch 197/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9241 - regression_loss: 1.6540 - classification_loss: 0.2701
# Epoch 197: saving model to snapshots2/resnet50_csv_197.h5
# 100/100 [==============================] - 20s 198ms/step - loss: 1.9241 - regression_loss: 1.6540 - classification_loss: 0.2701 - lr: 0.0000e+00
# Epoch 198/200
# 100/100 [==============================] - ETA: 0s - loss: 1.9611 - regression_loss: 1.6470 - classification_loss: 0.3141
# Epoch 198: saving model to snapshots2/resnet50_csv_198.h5
# 100/100 [==============================] - 25s 247ms/step - loss: 1.9611 - regression_loss: 1.6470 - classification_loss: 0.3141 - lr: 0.0000e+00
# Epoch 199/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0626 - regression_loss: 1.7395 - classification_loss: 0.3231
# Epoch 199: saving model to snapshots2/resnet50_csv_199.h5
# 100/100 [==============================] - 22s 215ms/step - loss: 2.0626 - regression_loss: 1.7395 - classification_loss: 0.3231 - lr: 0.0000e+00
# Epoch 200/200
# 100/100 [==============================] - ETA: 0s - loss: 2.0482 - regression_loss: 1.7058 - classification_loss: 0.3425
# Epoch 200: saving model to snapshots2/resnet50_csv_200.h5
# 100/100 [==============================] - 22s 217ms/step - loss: 2.0482 - regression_loss: 1.7058 - classification_loss: 0.3425 - lr: 0.0000e+00

# %%
# !python keras-retinanet/keras_retinanet/bin/convert_model.py /content/snapshots2/resnet50_csv_196.h5 /content/keras-retinanet/inference/myModel.h5
# Out:
# 2023-03-29 12:39:41.568634: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-29 12:39:41.568728: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-29 12:39:41.568745: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import os
model_path = '/content/snapshots2/resnet50_csv_196.h5' #os.path.join('/content/keras-retinanet/snapshots2', sorted(os.listdir('/content/keras-retinanet/snapshots2'), reverse=True)[0])
# evaluate model using test.csv

# !python /content/keras-retinanet/keras_retinanet/bin/evaluate.py \
--iou-threshold 0.5 \
--score-threshold 0.5 \
csv '/content/retinanet_test_annotations.csv' \
'keras-retinanet/classes.csv' \
{model_path} --convert-model
# Out:
# 2023-03-29 12:38:41.683878: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-29 12:38:41.683976: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-29 12:38:41.683994: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading model, this may take a second...
# 2023-03-29 12:38:44.286312: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Running network: 100% (78 of 78) |########| Elapsed Time: 0:00:40 Time:  0:00:40
# Parsing annotations: 100% (78 of 78) |####| Elapsed Time: 0:00:00 Time:  0:00:00
# 90 instances of class drone with average precision: 0.6928
# Inference time for 78 images: 0.4735
# mAP using the weighted average of precisions among classes: 0.6928
# mAP: 0.6928

# %%
from keras_retinanet import models

model = models.load_model('/content/snapshots2/resnet50_csv_197.h5', backbone_name='resnet50')
model = models.convert_model(model)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
from keras_retinanet.models import load_model

inference_model_path = '/content/keras-retinanet/inference/myModel.h5'
inference_model = load_model(inference_model_path, backbone_name='resnet50')
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
from keras_retinanet.utils.visualization import draw_box, draw_caption , label_color
from keras_retinanet.utils.image import preprocess_image, resize_image
from keras_retinanet.preprocessing.csv_generator import CSVGenerator
from keras_retinanet.utils.eval import evaluate

# Load the image
image_path = '/content/keras-retinanet/0149.jpg'
image = np.array(Image.open(image_path))

# Preprocess the image
image_processed = preprocess_image(image.astype(np.float32))
image_processed, scale = resize_image(image_processed)

# %%
# Run the prediction
boxes, scores, labels = inference_model.predict_on_batch(np.expand_dims(image_processed, axis=0))

# Correct for the image scale
boxes /= scale

# %%
# Set the confidence threshold
confidence_threshold = 0.5

# Visualize the predictions
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    if score >= confidence_threshold:
        color = label_color(label)
        b = box.astype(int)
        draw_box(image, b, color=color)
        
        caption = f"{'drone'}: {score:.2f}"
        draw_caption(image, b, caption)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
from keras_retinanet.preprocessing.csv_generator import CSVGenerator
val_annotations = '/content/retinanet_test_annotations.csv'
classes = 'keras-retinanet/classes.csv'
val_generator = CSVGenerator(val_annotations, classes)

# %%
average_precisions, inference_time = evaluate(
    val_generator,
    inference_model,
    score_threshold=0.5,  # Set the confidence threshold
    iou_threshold=0.5,     # Set the Intersection over Union (IoU) threshold
    max_detections=100,
    save_path=None
)
# Out:
# Running network: 100% (10 of 10) |#######| Elapsed Time: 0:00:00 Time:  0:00:00
# Parsing annotations: 100% (10 of 10) |###| Elapsed Time: 0:00:00 Time:  0:00:00

# %%
print(inference_time)
# Out:
# 0.043286895751953124

# %%
# Calculate the mAP
average_precisions_dict = average_precisions[0]
num_classes = len(average_precisions_dict)
sum_ap = sum([ap[0] for ap in average_precisions_dict.values()])

mAP = sum_ap / num_classes
print(f"Mean Average Precision (mAP): {mAP:.4f}")
# Out:
# Mean Average Precision (mAP): 0.5878

# %%
import numpy as np
from sklearn.metrics import f1_score, recall_score

# Generate predictions for the validation set
y_true = []  # List to store ground truth labels
y_pred = []  # List to store predicted labels

for index in range(val_generator.size()):
    image = val_generator.load_image(index)
    annotations = val_generator.load_annotations(index)
    
    # Get ground truth labels
    gt_labels = annotations['labels']
    
    # Get predicted labels
    image = np.expand_dims(image, axis=0)
    boxes, scores, labels = inference_model.predict(image)
    
    # Apply the confidence threshold
    pred_labels = labels[0][scores[0] >= 0.5]
    
    # Make sure y_true and y_pred have the same length
    n_gt_labels = len(gt_labels)
    n_pred_labels = len(pred_labels)

    if n_gt_labels < n_pred_labels:
        gt_labels = np.pad(gt_labels, (0, n_pred_labels - n_gt_labels), mode='constant', constant_values=-1)
    elif n_gt_labels > n_pred_labels:
        pred_labels = np.pad(pred_labels, (0, n_gt_labels - n_pred_labels), mode='constant', constant_values=-1)

    y_true.extend(gt_labels)
    y_pred.extend(pred_labels)

# Calculate recall and F1 score
recall = recall_score(y_true, y_pred, average='weighted', labels=np.unique(y_true))
f1 = f1_score(y_true, y_pred, average='weighted', labels=np.unique(y_true))

print("Recall:", recall)
print("F1 score:", f1)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 1s 1s/step
# Recall: 0.40707964601769914
# F1 score: 0.46084488228418763

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from keras_retinanet import models
from keras_retinanet.utils.eval import evaluate


average_precisions, recall, precision, f1 = evaluate(
    val_generator,
    inference_model,
    score_threshold=0.5,  # Set the confidence threshold
    iou_threshold=0.5,     # Set the Intersection over Union (IoU) threshold
    max_detections=100,
    save_path=None
)
# Out:
# Running network: 100% (10 of 10) |#######| Elapsed Time: 0:00:00 Time:  0:00:00
# Parsing annotations: 100% (10 of 10) |###| Elapsed Time: 0:00:00 Time:  0:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-74b574d32802> in <module>
#       4
#       5
# ----> 6 average_precisions, recall, precision, f1 = evaluate(
#       7     val_generator,
#       8     inference_model,
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
from keras_retinanet.utils.visualization import draw_box, draw_caption , label_color
from keras_retinanet.utils.image import preprocess_image, resize_image

# Load the image
image_path = '/content/keras-retinanet/22.JPEG'
image = np.array(Image.open(image_path))

# Preprocess the image
image_processed = preprocess_image(image.astype(np.float32))
image_processed, scale = resize_image(image_processed)

# %%
# Run the prediction
boxes, scores, labels = model.predict_on_batch(np.expand_dims(image_processed, axis=0))

# Correct for the image scale
boxes /= scale

# %%
# Set the confidence threshold
confidence_threshold = 0.3

# Visualize the predictions
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    if score >= confidence_threshold:
        color = label_color(label)
        b = box.astype(int)
        draw_box(image, b, color=color)
        
        caption = f"{'drone:'}: {score:.3f}"
        draw_caption(image, b, caption)
        score, label=score, label

plt.axis('off')
plt.imshow(image)
plt.rcParams['figure.figsize'] = [20, 20]
plt.show()


#plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#plt.axis('off')
#plt.show()

# %%
#convert yolo format to retinanet annotation csv
import os
import glob
from PIL import Image

IMAGE_DIR = "/content/sample_data/images"
ANNOTATION_DIR = "/content/sample_data/annotations"
OUTPUT_FILE = "retinanet_annotations.csv"
CLASS_NAMES = ['drone']  # Replace with your class names

def yolo_to_retinanet(yolo_annotation, img_width, img_height):
    class_id, x_center, y_center, width, height = map(float, yolo_annotation.strip().split())

    x_min = (x_center - width / 2) * img_width
    x_max = (x_center + width / 2) * img_width
    y_min = (y_center - height / 2) * img_height
    y_max = (y_center + height / 2) * img_height

    return int(class_id), x_min, y_min, x_max, y_max

with open(OUTPUT_FILE, 'w') as output_file:
    for ann_file in glob.glob(os.path.join(ANNOTATION_DIR, '*.txt')):
        img_file = os.path.join(IMAGE_DIR, os.path.splitext(os.path.basename(ann_file))[0] + '.jpg')
        img = Image.open(img_file)
        img_width, img_height = img.size

        with open(ann_file, 'r') as yolo_ann:
            for line in yolo_ann:
                class_id, x_min, y_min, x_max, y_max = yolo_to_retinanet(line, img_width, img_height)
                class_name = CLASS_NAMES[class_id]
                output_line = f"{img_file},{x_min},{y_min},{x_max},{y_max},{class_name}\n"
                output_file.write(output_line)

# %%
#visualizar las imagenes con su bbox
import cv2
import pandas as pd
import os
from google.colab.patches import cv2_imshow
IMAGE_DIR =  "/content/sample_data/images"
ANNOTATION_CSV = '/content/retinanet_annotations.csv'
IMAGE_NAME = '0001.jpg'  # Replace with the image name you want to display

def display_image_with_bounding_boxes(image_path, annotations_df):
    img = cv2.imread(image_path)
    for _, row in annotations_df.iterrows():
        x_min = int(row['x_min'])
        y_min = int(row['y_min'])
        x_max = int(row['x_max'])
        y_max = int(row['y_max'])
        class_name = row['class_name']
        img = cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        img = cv2.putText(img, class_name, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

    cv2_imshow(img)

annotations = pd.read_csv(ANNOTATION_CSV, names=['image_path', 'x_min', 'y_min', 'x_max', 'y_max', 'class_name'])

image_path = os.path.join(IMAGE_DIR, IMAGE_NAME)
image_annotations = annotations[annotations['image_path'] == image_path]
display_image_with_bounding_boxes(image_path, image_annotations)
# Out:
# <PIL.Image.Image image mode=RGB size=900x400 at 0x7F4178F19100>
